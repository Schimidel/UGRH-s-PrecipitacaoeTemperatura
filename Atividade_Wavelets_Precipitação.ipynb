# %%
#Importa as bibliotecas
import xarray as xr #Biblioteca para netcdf
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Abre os arquivos no drive
precip_GPCC = xr.open_dataset("/content/drive/MyDrive/Artigo_ABRHIDRO_Mudanças_Climáticas/Dados/precip_GPCC.nc").precip
precip_NCEP = xr.open_dataset("/content/drive/MyDrive/Artigo_ABRHIDRO_Mudanças_Climáticas/Dados/precip_NCEP.nc").prate

# %%
#Cria a série temporal com os dados de grade para a área do shape
mean_GPCC = precip_GPCC.mean(dim=['latitude', 'longitude'])
mean_NCEP = precip_NCEP.mean(dim=['latitude', 'longitude'])

# %%
#Calcula as anomalias mensais
anom_NCEP = mean_NCEP - mean_NCEP.sel(time=slice('1981', '2011')).mean(dim='time')
anom_GPCC = mean_GPCC - mean_GPCC.sel(time=slice('1981', '2011')).mean(dim='time')

# %%
#Transforma os dados para dataframe
df_NCEP = anom_NCEP.to_dataframe()
df_NCEP.index = df_NCEP.index.strftime('%Y-%m')
df_NCEP = df_NCEP.rename(columns={'prate' : "precip"})
df_GPCC = anom_GPCC.to_dataframe()
df_GPCC.index = df_GPCC.index.strftime('%Y-%m')

# %%
df_NCEP = df_NCEP.reset_index()
df_GPCC = df_GPCC.reset_index()

# %%
df_NCEP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932 entries, 0 to 931
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    932 non-null    object
#  1   precip  932 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.7+ KB

# %%
df_GPCC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1488 entries, 0 to 1487
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1488 non-null   object
#  1   precip  1488 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 23.4+ KB

# %%
fig, ax = plt.subplots(figsize=(12,6))
df_NCEP.precip.plot()
plt.xlabel('meses')
plt.ylabel('Precipitation Anomaly (mm/mes)')
plt.show()

# %%
# %%capture
# instala o wavelets
# !pip install pycwt

# %%
# primeiro importa o que vamos usar
import pycwt as wavelet
from pycwt.helpers import find
import numpy as np

# %% [markdown]
# # Wavelets NCEP

# %%
# algumas definições

# para 1° teste
dat = np.array(df_NCEP.precip) # simplesmente converte o meu Dataframe para um array usando o numpy
title = 'Precipitação NCEP'
label = 'Precipitation Anomaly'
units = 'mm/mes'
t0 = 0
dt = 1/12  # em anos

periodo_interesse = [0,1] # estou interessado em analizar a variância dentro de um período de interesse, em anos

N = dat.size
t = np.arange(0, N) * dt + t0

# %%
# vamos olhar nosso "t"
t
# Out:
# array([ 0.        ,  0.08333333,  0.16666667,  0.25      ,  0.33333333,
#         0.41666667,  0.5       ,  0.58333333,  0.66666667,  0.75      ,
#         0.83333333,  0.91666667,  1.        ,  1.08333333,  1.16666667,
#         1.25      ,  1.33333333,  1.41666667,  1.5       ,  1.58333333,
#         1.66666667,  1.75      ,  1.83333333,  1.91666667,  2.        ,
#         2.08333333,  2.16666667,  2.25      ,  2.33333333,  2.41666667,
#         2.5       ,  2.58333333,  2.66666667,  2.75      ,  2.83333333,
#         2.91666667,  3.        ,  3.08333333,  3.16666667,  3.25      ,
#         3.33333333,  3.41666667,  3.5       ,  3.58333333,  3.66666667,
#         3.75      ,  3.83333333,  3.91666667,  4.        ,  4.08333333,
#         4.16666667,  4.25      ,  4.33333333,  4.41666667,  4.5       ,
#        76.25      , 76.33333333, 76.41666667, 76.5       , 76.58333333,
#        76.66666667, 76.75      , 76.83333333, 76.91666667, 77.        ,
#        77.08333333, 77.16666667, 77.25      , 77.33333333, 77.41666667,
#        77.5       , 77.58333333])

# %%
p = np.polyfit(t - t0, dat, 1)
dat_notrend = dat - np.polyval(p, t - t0)
std = dat_notrend.std()  # Standard deviation
var = std ** 2  # Variance
dat_norm = dat_notrend / std  # Normalized dataset

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, figsize=(15,6))
ax[0].plot(t,dat)
ax[0].set_title('Natural')
ax[0].axhline(y=0,linestyle='--',color='r')

ax[1].plot(t,dat_norm)
ax[1].set_title('Normalizado')
ax[1].axhline(y=0,linestyle='--',color='r')

ax[2].plot(t,dat_notrend)
ax[2].set_title('No trend')
ax[2].axhline(y=0,linestyle='--',color='r')
plt.show()

# %% [markdown]
# A próxima etapa é definir alguns parâmetros de nossa análise de wavelet. Selecionamos a wavelet mãe, neste caso a wavelet de Morlet com ω0 = 6.

# %%
mother = wavelet.Morlet(6)
s0 = 2 * dt  # Escala inicial, neste caso 0.25 * 4 meses = 1 ano # note que isso pode variar dependendo de como seu dado está.
dj = 1 / 12  # 12 sub-oitavas por oitavas
J = 8 / dj  # 8 potências de dois com sub-oitavas dj
alpha, _, _ = wavelet.ar1(dat)  # Lag-1 autocorrelação para ruído vermelho !!!! muito importante !!!!!

# %% [markdown]
# **Se você não sabe o que é um ruido vermelho - PROCURE !**
#
# As rotinas a seguir realizam a transformação wavelet e a transformada wavelet inversa usando os parâmetros definidos acima. Como normalizamos nossa série temporal de entrada, multiplicamos a transformação inversa pelo desvio padrão.

# %%
wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat_norm, dt, dj, s0, J,mother)
#wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat, dt, dj, s0, J,mother)
iwave = wavelet.icwt(wave, scales, dt, dj, mother) * std

# %% [markdown]
# Calculamos a wavelet normalizada e os espectros de potência de Fourier, bem como os períodos equivalentes de Fourier para cada escala de wavelet.

# %%
power = (np.abs(wave)) ** 2
fft_power = np.abs(fft) ** 2
period = 1 / freqs

# %%
# Opcionalmente, também poderíamos retificar o espectro de potência
# de acordo com as sugestões propostas por Liu et al. (2007) [2]
#power /= scales[:, None]

# %% [markdown]
# Poderíamos parar neste ponto e traçar nossos resultados. No entanto, também estamos interessados no teste de significância de espectros de potência. A potência é significativa onde a relação potência / sig95> 1.

# %%
signif, fft_theor = wavelet.significance(1.0, dt, scales, 0, alpha,
                                         significance_level=0.75, #<---- veja
                                         wavelet=mother)
sig95 = np.ones([1, N]) * signif[:, None]
sig95 = power / sig95

# %% [markdown]
# Em seguida, calculamos o espectro wavelet global e determinamos seu nível de significância.

# %%
glbl_power = power.mean(axis=1)
dof = N - scales  # Correction for padding at edges
glbl_signif, tmp = wavelet.significance(var, dt, scales, 1, alpha,
                                        significance_level=0.75, dof=dof, #<---- veja
                                        wavelet=mother)

# %% [markdown]
# Também calculamos a média da escala entre 0 e X anos (de interesse) e seu nível de significância.

# %%
sel = find((period >= periodo_interesse[0]) & (period <= periodo_interesse[1]))
Cdelta = mother.cdelta
scale_avg = (scales * np.ones((N, 1))).transpose()
scale_avg = power / scale_avg  # As in Torrence and Compo (1998) equation 24
scale_avg = var * dj * dt / Cdelta * scale_avg[sel, :].sum(axis=0)
scale_avg_signif, tmp = wavelet.significance(var, dt, scales, 2, alpha,
                                             significance_level=0.75, #<---- veja
                                             dof=[scales[sel[0]],
                                                  scales[sel[-1]]],
                                             wavelet=mother)

# %% [markdown]
# Finalmente, plotamos nossos resultados em quatro subparcelas diferentes contendo a (i) anomalia da série original e a transformada wavelet inversa; (ii) o espectro de potência da wavelet (iii) o espectro global da wavelet e de Fourier; e (iv) o espectro de wavelet de média de alcance. Em todos os subgráficos, os níveis de significância são incluídos como linhas pontilhadas ou como linhas de contorno preenchidas.

# %%
### Receita de Bolo ###
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(11, 8))

# Primeiro sub-gráfico, a anomalia da série temporal original e wavelet inversa.
ax = plt.axes([0.1, 0.75, 0.65, 0.2])
ax.plot(t, iwave, '-', linewidth=1, color=[0.5, 0.5, 0.5])
ax.plot(t, dat, 'k', linewidth=1.5)
ax.set_title('a) {}'.format(title))
ax.set_ylabel(r'{} [{}]'.format(label, units))

# Segundo sub-gráfico, o espectro de potência da wavelet normalizada e significância
bx = plt.axes([0.1, 0.37, 0.65, 0.28], sharex=ax)
levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8, 16, 32]
bx.contourf(t, np.log2(period), np.log2(power), levels=np.log2(levels), extend='both', cmap=plt.cm.rainbow)
extent = [t.min(), t.max(), np.log2(period.min()), np.log2(period.max())]
bx.contour(t, np.log2(period), sig95, levels=[-99, 1], colors='k', linewidths=2, extent=extent)
bx.fill(np.concatenate([t, t[-1:] + dt, t[-1:] + dt, t[:1] - dt, t[:1] - dt]),
        np.concatenate([np.log2(coi), [1e-9], np.log2(period[-1:]), np.log2(period[-1:]), [1e-9]]),
        'k', alpha=0.3, hatch='x')
bx.set_title('b) {} Wavelet Power Spectrum ({})'.format(label, mother.name))
bx.set_ylabel('Period (Years)')

Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())), np.ceil(np.log2(period.max())))
bx.set_yticks(np.log2(Yticks))
bx.set_yticklabels(Yticks)

# Terceiro sub-gráfico, wavelet global e espectros de potência de Fourier e teóricos
cx = plt.axes([0.77, 0.37, 0.2, 0.28], sharey=bx)
cx.plot(glbl_signif, np.log2(period), 'k--')
cx.plot(var * fft_theor, np.log2(period), '--', color='#cccccc')
cx.plot(var * fft_power, np.log2(1./fftfreqs), '-', color='#cccccc', linewidth=1.)
cx.plot(var * glbl_power, np.log2(period), 'k-', linewidth=1.5)

cx.set_title('c) Global Wavelet Spectrum')
cx.set_xlabel(r'Power [({})^2]'.format(units))
#cx.set_xlim([0, glbl_power.max() + var]) # sinto que não há necessidade de limitar aqui
cx.set_ylim(np.log2([period.min(), period.max()]))
cx.set_yticks(np.log2(Yticks))
cx.set_yticklabels(Yticks)
plt.setp(cx.get_yticklabels(), visible=False)

# Quarto sub-gráfico, o espectro de ondas médias da escala.
dx = plt.axes([0.1, 0.07, 0.65, 0.2], sharex=ax)
dx.axhline(scale_avg_signif, color='k', linestyle='--', linewidth=1.)
dx.plot(t, scale_avg, 'k-', linewidth=1.5)
dx.set_title('d) {}--{} Anos (scale-averaged power)'.format(periodo_interesse[0], periodo_interesse[1]))
dx.set_xlabel('Time (Year)')
dx.set_ylabel(r'Average varianceee [{}]'.format(units))
ax.set_xlim([t.min(), t.max()])

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Realizando a decomposição sazonal da série temporal de precipitação
decomp = seasonal_decompose(df_NCEP['precip'], model='additive', period=12,two_sided=True)  # Ajuste o período conforme necessário

# Obtendo a componente sazonal
sazonal = decomp.seasonal

# Removendo a componente sazonal da série temporal de SST
no_season = df_NCEP['precip'] - sazonal

# %%
no_season
# Out:
# 0     -168.147405
# 1     -132.771444
# 2     -117.683014
# 3     -114.096127
# 4      -75.110431
#           ...
# 927     65.805713
# 928    -32.791929
# 929     34.757756
# 930    -31.306021
# 931    -14.403155
# Length: 932, dtype: float64

# %%
# algumas definições

# para 1° teste
dat = np.array(no_season) # simplesmente converte o meu Dataframe para um array usando o numpy
title = 'Precipitation NCEP'
label = 'Precipitation Anomaly'
units = 'mm/month anomaly'
t0 = 0
dt = 1/12  # em anos

periodo_interesse = [0,1] # estou interessado em analizar a variância dentro de um período de interesse, em anos

N = dat.size
t = np.arange(0, N) * dt + t0

# %%
# vamos olhar nosso "t"
t
# Out:
# array([ 0.        ,  0.08333333,  0.16666667,  0.25      ,  0.33333333,
#        72.08333333, 72.16666667, 72.25      , 72.33333333, 72.41666667,
#        72.5       , 72.58333333, 72.66666667, 72.75      , 72.83333333,
#        72.91666667, 73.        , 73.08333333, 73.16666667, 73.25      ,
#        73.33333333, 73.41666667, 73.5       , 73.58333333, 73.66666667,
#        73.75      , 73.83333333, 73.91666667, 74.        , 74.08333333,
#        74.16666667, 74.25      , 74.33333333, 74.41666667, 74.5       ,
#        74.58333333, 74.66666667, 74.75      , 74.83333333, 74.91666667,
#        75.        , 75.08333333, 75.16666667, 75.25      , 75.33333333,
#        75.41666667, 75.5       , 75.58333333, 75.66666667, 75.75      ,
#        75.83333333, 75.91666667, 76.        , 76.08333333, 76.16666667,
#        76.25      , 76.33333333, 76.41666667, 76.5       , 76.58333333,
#        76.66666667, 76.75      , 76.83333333, 76.91666667, 77.        ,
#        77.08333333, 77.16666667, 77.25      , 77.33333333, 77.41666667,
#        77.5       , 77.58333333])

# %%
p = np.polyfit(t - t0, dat, 1)
dat_notrend = dat - np.polyval(p, t - t0)
std = dat_notrend.std()  # Standard deviation
var = std ** 2  # Variance
dat_norm = dat_notrend / std  # Normalized dataset

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, figsize=(15,6))
ax[0].plot(t,dat)
ax[0].set_title('Natural')
ax[0].axhline(y=0,linestyle='--',color='r')

ax[1].plot(t,dat_norm)
ax[1].set_title('Normalizado')
ax[1].axhline(y=0,linestyle='--',color='r')

ax[2].plot(t,dat_notrend)
ax[2].set_title('No trend')
ax[2].axhline(y=0,linestyle='--',color='r')
plt.show()

# %% [markdown]
# A próxima etapa é definir alguns parâmetros de nossa análise de wavelet. Selecionamos a wavelet mãe, neste caso a wavelet de Morlet com ω0 = 6.

# %%
mother = wavelet.Morlet(6)
s0 = 2 * dt  # Escala inicial, neste caso 0.25 * 4 meses = 1 ano # note que isso pode variar dependendo de como seu dado está.
dj = 1 / 12  # 12 sub-oitavas por oitavas
J = 8 / dj  # 8 potências de dois com sub-oitavas dj
alpha, _, _ = wavelet.ar1(dat)  # Lag-1 autocorrelação para ruído vermelho !!!! muito importante !!!!!

# %% [markdown]
# **Se você não sabe o que é um ruido vermelho - PROCURE !**
#
# As rotinas a seguir realizam a transformação wavelet e a transformada wavelet inversa usando os parâmetros definidos acima. Como normalizamos nossa série temporal de entrada, multiplicamos a transformação inversa pelo desvio padrão.

# %%
wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat_norm, dt, dj, s0, J,mother)
#wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat, dt, dj, s0, J,mother)
iwave = wavelet.icwt(wave, scales, dt, dj, mother) * std

# %% [markdown]
# Calculamos a wavelet normalizada e os espectros de potência de Fourier, bem como os períodos equivalentes de Fourier para cada escala de wavelet.

# %%
power = (np.abs(wave)) ** 2
fft_power = np.abs(fft) ** 2
period = 1 / freqs

# %%
# Opcionalmente, também poderíamos retificar o espectro de potência
# de acordo com as sugestões propostas por Liu et al. (2007) [2]
#power /= scales[:, None]

# %% [markdown]
# Poderíamos parar neste ponto e traçar nossos resultados. No entanto, também estamos interessados no teste de significância de espectros de potência. A potência é significativa onde a relação potência / sig95> 1.

# %%
signif, fft_theor = wavelet.significance(1.0, dt, scales, 0, alpha,
                                         significance_level=0.75, #<---- veja
                                         wavelet=mother)
sig95 = np.ones([1, N]) * signif[:, None]
sig95 = power / sig95

# %% [markdown]
# Em seguida, calculamos o espectro wavelet global e determinamos seu nível de significância.

# %%
glbl_power = power.mean(axis=1)
dof = N - scales  # Correction for padding at edges
glbl_signif, tmp = wavelet.significance(var, dt, scales, 1, alpha,
                                        significance_level=0.75, dof=dof, #<---- veja
                                        wavelet=mother)

# %% [markdown]
# Também calculamos a média da escala entre 0 e X anos (de interesse) e seu nível de significância.

# %%
sel = find((period >= periodo_interesse[0]) & (period <= periodo_interesse[1]))
Cdelta = mother.cdelta
scale_avg = (scales * np.ones((N, 1))).transpose()
scale_avg = power / scale_avg  # As in Torrence and Compo (1998) equation 24
scale_avg = var * dj * dt / Cdelta * scale_avg[sel, :].sum(axis=0)
scale_avg_signif, tmp = wavelet.significance(var, dt, scales, 2, alpha,
                                             significance_level=0.75, #<---- veja
                                             dof=[scales[sel[0]],
                                                  scales[sel[-1]]],
                                             wavelet=mother)

# %% [markdown]
# Finalmente, plotamos nossos resultados em quatro subparcelas diferentes contendo a (i) anomalia da série original e a transformada wavelet inversa; (ii) o espectro de potência da wavelet (iii) o espectro global da wavelet e de Fourier; e (iv) o espectro de wavelet de média de alcance. Em todos os subgráficos, os níveis de significância são incluídos como linhas pontilhadas ou como linhas de contorno preenchidas.

# %%
### Receita de Bolo ###
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # Importar pandas para trabalhar com o DataFrame

fig = plt.figure(figsize=(6, 8))

# Obtenha o ano inicial da coluna 'time' do dataframe
start_year = int(df_NCEP['time'].iloc[0].split('-')[0])
# Obtenha o ano final da coluna 'time' do dataframe
end_year = int(df_NCEP['time'].iloc[-1].split('-')[0]) + (int(df_NCEP['time'].iloc[-1].split('-')[1])/12) # Adiciona a fração do ano para o último mês


# Ajuste o array de tempo 't' para incluir o ano inicial
N = dat.size
# Crie o array de tempo com base no ano inicial e dt
t = np.arange(start_year, start_year + N * dt, dt)[:N]


# Primeiro sub-gráfico, a anomalia da série temporal original e wavelet inversa.
ax = plt.axes([0.1, 0.75, 0.65, 0.2])   # mantém no topo
ax.plot(t, iwave, '-', linewidth=1, color=[0.5, 0.5, 0.5])
ax.plot(t, dat, 'k', linewidth=1.5)
ax.set_title('a) {}'.format(title), fontsize=8)
ax.set_ylabel(r'{} [{}]'.format(label, units), fontsize=8) #Fonte do eixo y primeira figura
ax.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x

# Segundo sub-gráfico, o espectro de potência da wavelet normalizada e significância
bx = plt.axes([0.1, 0.39, 0.65, 0.28], sharex=ax)
levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8, 16, 32]
bx.contourf(t, np.log2(period), np.log2(power), levels=np.log2(levels), extend='both', cmap=plt.cm.rainbow)
extent = [t.min(), t.max(), np.log2(period.min()), np.log2(period.max())]
bx.contour(t, np.log2(period), sig95, levels=[-99, 1], colors='k', linewidths=2, extent=extent)
bx.fill(np.concatenate([t, t[-1:] + dt, t[-1:] + dt, t[:1] - dt, t[:1] - dt]),
        np.concatenate([np.log2(coi), [1e-9], np.log2(period[-1:]), np.log2(period[-1:]), [1e-9]]),
        'k', alpha=0.3, hatch='x')
bx.set_title('b) {} Wavelet Power Spectrum ({})'.format(label, mother.name), fontsize=8)
bx.set_ylabel('Period (Years)', fontsize=8)

Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())), np.ceil(np.log2(period.max())))
bx.set_yticks(np.log2(Yticks))
bx.set_yticklabels(Yticks)
bx.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x


# Terceiro sub-gráfico, wavelet global e espectros de potência de Fourier e teóricos
cx = plt.axes([0.77, 0.39, 0.2, 0.28], sharey=bx)
cx.plot(glbl_signif, np.log2(period), 'k--')
cx.plot(var * fft_theor, np.log2(period), '--', color='#cccccc')
cx.plot(var * fft_power, np.log2(1./fftfreqs), '-', color='#cccccc', linewidth=1.)
cx.plot(var * glbl_power, np.log2(period), 'k-', linewidth=1.5)

cx.set_title('c) Global Wavelet Spectrum', fontsize=8)
cx.set_xlabel(r'Power [({})^2]'.format(units), fontsize=8)
#cx.set_xlim([0, glbl_power.max() + var]) # sinto que não há necessidade de limitar aqui
cx.set_ylim(np.log2([period.min(), period.max()]))
cx.set_yticks(np.log2(Yticks))
cx.set_yticklabels(Yticks)
plt.setp(cx.get_yticklabels(), visible=False)

# Quarto sub-gráfico, o espectro de ondas médias da escala.
dx = plt.axes([0.1, 0.12, 0.65, 0.2], sharex=ax)
dx.axhline(scale_avg_signif, color='k', linestyle='--', linewidth=1.)
dx.plot(t, scale_avg, 'k-', linewidth=1.5)
dx.set_title('d) {}--{} Anos (scale-averaged power)'.format(periodo_interesse[0], periodo_interesse[1]), fontsize=8)
dx.set_xlabel('Time (Year)')
dx.set_ylabel(r'Average variance [{}]'.format(units), fontsize=8)
dx.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x

plt.savefig("Wavelets_NCEP.png", dpi=600)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # Wavelets GPCC

# %%
# algumas definições

# para 1° teste
dat = np.array(df_GPCC.precip) # simplesmente converte o meu Dataframe para um array usando o numpy
title = 'Precipitation GPCC'
label = 'Precipitation Anomaly'
units = 'anomaly mm/mes'
t0 = 0
dt = 1/12  # em anos

periodo_interesse = [0,1] # estou interessado em analizar a variância dentro de um período de interesse, em anos

N = dat.size
t = np.arange(0, N) * dt + t0

# %%
# vamos olhar nosso "t"
t
# Out:
# array([0.00000000e+00, 8.33333333e-02, 1.66666667e-01, ...,
#        1.23750000e+02, 1.23833333e+02, 1.23916667e+02])

# %%
p = np.polyfit(t - t0, dat, 1)
dat_notrend = dat - np.polyval(p, t - t0)
std = dat_notrend.std()  # Standard deviation
var = std ** 2  # Variance
dat_norm = dat_notrend / std  # Normalized dataset

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, figsize=(15,6))
ax[0].plot(t,dat)
ax[0].set_title('Natural')
ax[0].axhline(y=0,linestyle='--',color='r')

ax[1].plot(t,dat_norm)
ax[1].set_title('Normalizado')
ax[1].axhline(y=0,linestyle='--',color='r')

ax[2].plot(t,dat_notrend)
ax[2].set_title('No trend')
ax[2].axhline(y=0,linestyle='--',color='r')
plt.show()

# %% [markdown]
# A próxima etapa é definir alguns parâmetros de nossa análise de wavelet. Selecionamos a wavelet mãe, neste caso a wavelet de Morlet com ω0 = 6.

# %%
mother = wavelet.Morlet(6)
s0 = 2 * dt  # Escala inicial, neste caso 0.25 * 4 meses = 1 ano # note que isso pode variar dependendo de como seu dado está.
dj = 1 / 12  # 12 sub-oitavas por oitavas
J = 8 / dj  # 8 potências de dois com sub-oitavas dj
alpha, _, _ = wavelet.ar1(dat)  # Lag-1 autocorrelação para ruído vermelho !!!! muito importante !!!!!

# %% [markdown]
# **Se você não sabe o que é um ruido vermelho - PROCURE !**
#
# As rotinas a seguir realizam a transformação wavelet e a transformada wavelet inversa usando os parâmetros definidos acima. Como normalizamos nossa série temporal de entrada, multiplicamos a transformação inversa pelo desvio padrão.

# %%
wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat_norm, dt, dj, s0, J,mother)
#wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat, dt, dj, s0, J,mother)
iwave = wavelet.icwt(wave, scales, dt, dj, mother) * std

# %% [markdown]
# Calculamos a wavelet normalizada e os espectros de potência de Fourier, bem como os períodos equivalentes de Fourier para cada escala de wavelet.

# %%
power = (np.abs(wave)) ** 2
fft_power = np.abs(fft) ** 2
period = 1 / freqs

# %%
# Opcionalmente, também poderíamos retificar o espectro de potência
# de acordo com as sugestões propostas por Liu et al. (2007) [2]
#power /= scales[:, None]

# %% [markdown]
# Poderíamos parar neste ponto e traçar nossos resultados. No entanto, também estamos interessados no teste de significância de espectros de potência. A potência é significativa onde a relação potência / sig95> 1.

# %%
signif, fft_theor = wavelet.significance(1.0, dt, scales, 0, alpha,
                                         significance_level=0.75, #<---- veja
                                         wavelet=mother)
sig95 = np.ones([1, N]) * signif[:, None]
sig95 = power / sig95

# %% [markdown]
# Em seguida, calculamos o espectro wavelet global e determinamos seu nível de significância.

# %%
glbl_power = power.mean(axis=1)
dof = N - scales  # Correction for padding at edges
glbl_signif, tmp = wavelet.significance(var, dt, scales, 1, alpha,
                                        significance_level=0.75, dof=dof, #<---- veja
                                        wavelet=mother)

# %% [markdown]
# Também calculamos a média da escala entre 0 e X anos (de interesse) e seu nível de significância.

# %%
sel = find((period >= periodo_interesse[0]) & (period <= periodo_interesse[1]))
Cdelta = mother.cdelta
scale_avg = (scales * np.ones((N, 1))).transpose()
scale_avg = power / scale_avg  # As in Torrence and Compo (1998) equation 24
scale_avg = var * dj * dt / Cdelta * scale_avg[sel, :].sum(axis=0)
scale_avg_signif, tmp = wavelet.significance(var, dt, scales, 2, alpha,
                                             significance_level=0.75, #<---- veja
                                             dof=[scales[sel[0]],
                                                  scales[sel[-1]]],
                                             wavelet=mother)

# %% [markdown]
# Finalmente, plotamos nossos resultados em quatro subparcelas diferentes contendo a (i) anomalia da série original e a transformada wavelet inversa; (ii) o espectro de potência da wavelet (iii) o espectro global da wavelet e de Fourier; e (iv) o espectro de wavelet de média de alcance. Em todos os subgráficos, os níveis de significância são incluídos como linhas pontilhadas ou como linhas de contorno preenchidas.

# %%
### Receita de Bolo ###
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(11, 8))

# Primeiro sub-gráfico, a anomalia da série temporal original e wavelet inversa.
ax = plt.axes([0.1, 0.75, 0.65, 0.2])
ax.plot(t, iwave, '-', linewidth=1, color=[0.5, 0.5, 0.5])
ax.plot(t, dat, 'k', linewidth=1.5)
ax.set_title('a) {}'.format(title))
ax.set_ylabel(r'{} [{}]'.format(label, units))

# Segundo sub-gráfico, o espectro de potência da wavelet normalizada e significância
bx = plt.axes([0.1, 0.37, 0.65, 0.28], sharex=ax)
levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8, 16, 32]
bx.contourf(t, np.log2(period), np.log2(power), levels=np.log2(levels), extend='both', cmap=plt.cm.rainbow)
extent = [t.min(), t.max(), np.log2(period.min()), np.log2(period.max())]
bx.contour(t, np.log2(period), sig95, levels=[-99, 1], colors='k', linewidths=2, extent=extent)
bx.fill(np.concatenate([t, t[-1:] + dt, t[-1:] + dt, t[:1] - dt, t[:1] - dt]),
        np.concatenate([np.log2(coi), [1e-9], np.log2(period[-1:]), np.log2(period[-1:]), [1e-9]]),
        'k', alpha=0.3, hatch='x')
bx.set_title('b) {} Wavelet Power Spectrum ({})'.format(label, mother.name))
bx.set_ylabel('Period (Years)')

Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())), np.ceil(np.log2(period.max())))
bx.set_yticks(np.log2(Yticks))
bx.set_yticklabels(Yticks)

# Terceiro sub-gráfico, wavelet global e espectros de potência de Fourier e teóricos
cx = plt.axes([0.77, 0.37, 0.2, 0.28], sharey=bx)
cx.plot(glbl_signif, np.log2(period), 'k--')
cx.plot(var * fft_theor, np.log2(period), '--', color='#cccccc')
cx.plot(var * fft_power, np.log2(1./fftfreqs), '-', color='#cccccc', linewidth=1.)
cx.plot(var * glbl_power, np.log2(period), 'k-', linewidth=1.5)

cx.set_title('c) Global Wavelet Spectrum')
cx.set_xlabel(r'Power [({})^2]'.format(units))
#cx.set_xlim([0, glbl_power.max() + var]) # sinto que não há necessidade de limitar aqui
cx.set_ylim(np.log2([period.min(), period.max()]))
cx.set_yticks(np.log2(Yticks))
cx.set_yticklabels(Yticks)
plt.setp(cx.get_yticklabels(), visible=False)

# Quarto sub-gráfico, o espectro de ondas médias da escala.
dx = plt.axes([0.1, 0.07, 0.65, 0.2], sharex=ax)
dx.axhline(scale_avg_signif, color='k', linestyle='--', linewidth=1.)
dx.plot(t, scale_avg, 'k-', linewidth=1.5)
dx.set_title('d) {}--{} Anos (scale-averaged power)'.format(periodo_interesse[0], periodo_interesse[1]))
dx.set_xlabel('Time (Year)')
dx.set_ylabel(r'Average variance [{}]'.format(units))
ax.set_xlim([t.min(), t.max()])

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Realizando a decomposição sazonal da série temporal de precipitação
decomp = seasonal_decompose(df_GPCC['precip'], model='additive', period=12,two_sided=True)  # Ajuste o período conforme necessário

# Obtendo a componente sazonal
sazonal = decomp.seasonal

# Removendo a componente sazonal da série temporal de SST
no_season = df_GPCC['precip'] - sazonal

# %%
no_season
# Out:
# 0       11.596771
# 1      -20.472221
# 2      -21.686483
# 3       23.564074
# 4      -25.748594
#           ...
# 1483   -10.751340
# 1484   -49.766961
# 1485   -22.904470
# 1486    44.009298
# 1487     1.567920
# Length: 1488, dtype: float64

# %%
# algumas definições

# para 1° teste
dat = np.array(no_season) # simplesmente converte o meu Dataframe para um array usando o numpy
title = 'GPCC Precipitation'
label = 'Precipitation Anomaly'
units = 'mm/mes'
t0 = 0
dt = 1/12  # em anos

periodo_interesse = [0,1] # estou interessado em analizar a variância dentro de um período de interesse, em anos

N = dat.size
t = np.arange(0, N) * dt + t0

# %%
# vamos olhar nosso "t"
t
# Out:
# array([0.00000000e+00, 8.33333333e-02, 1.66666667e-01, ...,
#        1.23750000e+02, 1.23833333e+02, 1.23916667e+02])

# %%
p = np.polyfit(t - t0, dat, 1)
dat_notrend = dat - np.polyval(p, t - t0)
std = dat_notrend.std()  # Standard deviation
var = std ** 2  # Variance
dat_norm = dat_notrend / std  # Normalized dataset

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, figsize=(15,6))
ax[0].plot(t,dat)
ax[0].set_title('Natural')
ax[0].axhline(y=0,linestyle='--',color='r')

ax[1].plot(t,dat_norm)
ax[1].set_title('Normalizado')
ax[1].axhline(y=0,linestyle='--',color='r')

ax[2].plot(t,dat_notrend)
ax[2].set_title('No trend')
ax[2].axhline(y=0,linestyle='--',color='r')
plt.show()

# %% [markdown]
# A próxima etapa é definir alguns parâmetros de nossa análise de wavelet. Selecionamos a wavelet mãe, neste caso a wavelet de Morlet com ω0 = 6.

# %%
mother = wavelet.Morlet(6)
s0 = 2 * dt  # Escala inicial, neste caso 0.25 * 4 meses = 1 ano # note que isso pode variar dependendo de como seu dado está.
dj = 1 / 12  # 12 sub-oitavas por oitavas
J = 8 / dj  # 8 potências de dois com sub-oitavas dj
alpha, _, _ = wavelet.ar1(dat)  # Lag-1 autocorrelação para ruído vermelho !!!! muito importante !!!!!

# %% [markdown]
# **Se você não sabe o que é um ruido vermelho - PROCURE !**
#
# As rotinas a seguir realizam a transformação wavelet e a transformada wavelet inversa usando os parâmetros definidos acima. Como normalizamos nossa série temporal de entrada, multiplicamos a transformação inversa pelo desvio padrão.

# %%
wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat_norm, dt, dj, s0, J,mother)
#wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat, dt, dj, s0, J,mother)
iwave = wavelet.icwt(wave, scales, dt, dj, mother) * std

# %% [markdown]
# Calculamos a wavelet normalizada e os espectros de potência de Fourier, bem como os períodos equivalentes de Fourier para cada escala de wavelet.

# %%
power = (np.abs(wave)) ** 2
fft_power = np.abs(fft) ** 2
period = 1 / freqs

# %%
# Opcionalmente, também poderíamos retificar o espectro de potência
# de acordo com as sugestões propostas por Liu et al. (2007) [2]
#power /= scales[:, None]

# %% [markdown]
# Poderíamos parar neste ponto e traçar nossos resultados. No entanto, também estamos interessados no teste de significância de espectros de potência. A potência é significativa onde a relação potência / sig95> 1.

# %%
signif, fft_theor = wavelet.significance(1.0, dt, scales, 0, alpha,
                                         significance_level=0.75, #<---- veja
                                         wavelet=mother)
sig95 = np.ones([1, N]) * signif[:, None]
sig95 = power / sig95

# %% [markdown]
# Em seguida, calculamos o espectro wavelet global e determinamos seu nível de significância.

# %%
glbl_power = power.mean(axis=1)
dof = N - scales  # Correction for padding at edges
glbl_signif, tmp = wavelet.significance(var, dt, scales, 1, alpha,
                                        significance_level=0.75, dof=dof, #<---- veja
                                        wavelet=mother)

# %% [markdown]
# Também calculamos a média da escala entre 0 e X anos (de interesse) e seu nível de significância.

# %%
sel = find((period >= periodo_interesse[0]) & (period <= periodo_interesse[1]))
Cdelta = mother.cdelta
scale_avg = (scales * np.ones((N, 1))).transpose()
scale_avg = power / scale_avg  # As in Torrence and Compo (1998) equation 24
scale_avg = var * dj * dt / Cdelta * scale_avg[sel, :].sum(axis=0)
scale_avg_signif, tmp = wavelet.significance(var, dt, scales, 2, alpha,
                                             significance_level=0.75, #<---- veja
                                             dof=[scales[sel[0]],
                                                  scales[sel[-1]]],
                                             wavelet=mother)

# %% [markdown]
# Finalmente, plotamos nossos resultados em quatro subparcelas diferentes contendo a (i) anomalia da série original e a transformada wavelet inversa; (ii) o espectro de potência da wavelet (iii) o espectro global da wavelet e de Fourier; e (iv) o espectro de wavelet de média de alcance. Em todos os subgráficos, os níveis de significância são incluídos como linhas pontilhadas ou como linhas de contorno preenchidas.

# %%
### Receita de Bolo ###
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # Importar pandas para trabalhar com o DataFrame

fig = plt.figure(figsize=(11, 8))

# Obtenha o ano inicial da coluna 'time' do dataframe
start_year = int(df_GPCC['time'].iloc[0].split('-')[0])
# Obtenha o ano final da coluna 'time' do dataframe
end_year = int(df_GPCC['time'].iloc[-1].split('-')[0]) + (int(df_NCEP['time'].iloc[-1].split('-')[1])/12) # Adiciona a fração do ano para o último mês


# Ajuste o array de tempo 't' para incluir o ano inicial
N = dat.size
# Crie o array de tempo com base no ano inicial e dt
t = np.arange(start_year, start_year + N * dt, dt)[:N]


# Primeiro sub-gráfico, a anomalia da série temporal original e wavelet inversa.
ax = plt.axes([0.1, 0.75, 0.65, 0.2])
ax.plot(t, iwave, '-', linewidth=1, color=[0.5, 0.5, 0.5])
ax.plot(t, dat, 'k', linewidth=1.5)
ax.set_title('a) {}'.format(title))
ax.set_ylabel(r'{} [{}]'.format(label, units))
ax.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x

# Segundo sub-gráfico, o espectro de potência da wavelet normalizada e significância
bx = plt.axes([0.1, 0.37, 0.65, 0.28], sharex=ax)
levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8, 16, 32]
bx.contourf(t, np.log2(period), np.log2(power), levels=np.log2(levels), extend='both', cmap=plt.cm.rainbow)
extent = [t.min(), t.max(), np.log2(period.min()), np.log2(period.max())]
bx.contour(t, np.log2(period), sig95, levels=[-99, 1], colors='k', linewidths=2, extent=extent)
bx.fill(np.concatenate([t, t[-1:] + dt, t[-1:] + dt, t[:1] - dt, t[:1] - dt]),
        np.concatenate([np.log2(coi), [1e-9], np.log2(period[-1:]), np.log2(period[-1:]), [1e-9]]),
        'k', alpha=0.3, hatch='x')
bx.set_title('b) {} Wavelet Power Spectrum ({})'.format(label, mother.name))
bx.set_ylabel('Period (Years)')

Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())), np.ceil(np.log2(period.max())))
bx.set_yticks(np.log2(Yticks))
bx.set_yticklabels(Yticks)
bx.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x


# Terceiro sub-gráfico, wavelet global e espectros de potência de Fourier e teóricos
cx = plt.axes([0.77, 0.37, 0.2, 0.28], sharey=bx)
cx.plot(glbl_signif, np.log2(period), 'k--')
cx.plot(var * fft_theor, np.log2(period), '--', color='#cccccc')
cx.plot(var * fft_power, np.log2(1./fftfreqs), '-', color='#cccccc', linewidth=1.)
cx.plot(var * glbl_power, np.log2(period), 'k-', linewidth=1.5)

cx.set_title('c) Global Wavelet Spectrum')
cx.set_xlabel(r'Power [({})^2]'.format(units))
#cx.set_xlim([0, glbl_power.max() + var]) # sinto que não há necessidade de limitar aqui
cx.set_ylim(np.log2([period.min(), period.max()]))
cx.set_yticks(np.log2(Yticks))
cx.set_yticklabels(Yticks)
plt.setp(cx.get_yticklabels(), visible=False)

# Quarto sub-gráfico, o espectro de ondas médias da escala.
dx = plt.axes([0.1, 0.07, 0.65, 0.2], sharex=ax)
dx.axhline(scale_avg_signif, color='k', linestyle='--', linewidth=1.)
dx.plot(t, scale_avg, 'k-', linewidth=1.5)
dx.set_title('d) {}--{} Anos (scale-averaged power)'.format(periodo_interesse[0], periodo_interesse[1]))
dx.set_xlabel('Time (Year)')
dx.set_ylabel(r'Average variance [{}]'.format(units))
dx.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x

plt.savefig("Wavelets_GPCC.png", dpi=600)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
### Receita de Bolo ###
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # Importar pandas para trabalhar com o DataFrame

fig = plt.figure(figsize=(6, 8))

# Obtenha o ano inicial da coluna 'time' do dataframe
start_year = int(df_GPCC['time'].iloc[0].split('-')[0])
# Obtenha o ano final da coluna 'time' do dataframe
end_year = int(df_GPCC['time'].iloc[-1].split('-')[0]) + (int(df_NCEP['time'].iloc[-1].split('-')[1])/12) # Adiciona a fração do ano para o último mês


# Ajuste o array de tempo 't' para incluir o ano inicial
N = dat.size
# Crie o array de tempo com base no ano inicial e dt
t = np.arange(start_year, start_year + N * dt, dt)[:N]


# Primeiro sub-gráfico, a anomalia da série temporal original e wavelet inversa.
ax = plt.axes([0.1, 0.75, 0.65, 0.2])   # mantém no topo
ax.plot(t, iwave, '-', linewidth=1, color=[0.5, 0.5, 0.5])
ax.plot(t, dat, 'k', linewidth=1.5)
ax.set_title('a) {}'.format(title), fontsize=8)
ax.set_ylabel(r'{} [{}]'.format(label, units), fontsize=8) #Fonte do eixo y primeira figura
ax.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x

# Segundo sub-gráfico, o espectro de potência da wavelet normalizada e significância
bx = plt.axes([0.1, 0.39, 0.65, 0.28], sharex=ax)
levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8, 16, 32]
bx.contourf(t, np.log2(period), np.log2(power), levels=np.log2(levels), extend='both', cmap=plt.cm.rainbow)
extent = [t.min(), t.max(), np.log2(period.min()), np.log2(period.max())]
bx.contour(t, np.log2(period), sig95, levels=[-99, 1], colors='k', linewidths=2, extent=extent)
bx.fill(np.concatenate([t, t[-1:] + dt, t[-1:] + dt, t[:1] - dt, t[:1] - dt]),
        np.concatenate([np.log2(coi), [1e-9], np.log2(period[-1:]), np.log2(period[-1:]), [1e-9]]),
        'k', alpha=0.3, hatch='x')
bx.set_title('b) {} Wavelet Power Spectrum ({})'.format(label, mother.name), fontsize=8)
bx.set_ylabel('Period (Years)', fontsize=8)

Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())), np.ceil(np.log2(period.max())))
bx.set_yticks(np.log2(Yticks))
bx.set_yticklabels(Yticks)
bx.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x


# Terceiro sub-gráfico, wavelet global e espectros de potência de Fourier e teóricos
cx = plt.axes([0.77, 0.39, 0.2, 0.28], sharey=bx)
cx.plot(glbl_signif, np.log2(period), 'k--')
cx.plot(var * fft_theor, np.log2(period), '--', color='#cccccc')
cx.plot(var * fft_power, np.log2(1./fftfreqs), '-', color='#cccccc', linewidth=1.)
cx.plot(var * glbl_power, np.log2(period), 'k-', linewidth=1.5)

cx.set_title('c) Global Wavelet Spectrum', fontsize=8)
cx.set_xlabel(r'Power [({})^2]'.format(units), fontsize=8)
#cx.set_xlim([0, glbl_power.max() + var]) # sinto que não há necessidade de limitar aqui
cx.set_ylim(np.log2([period.min(), period.max()]))
cx.set_yticks(np.log2(Yticks))
cx.set_yticklabels(Yticks)
plt.setp(cx.get_yticklabels(), visible=False)

# Quarto sub-gráfico, o espectro de ondas médias da escala.
dx = plt.axes([0.1, 0.12, 0.65, 0.2], sharex=ax)
dx.axhline(scale_avg_signif, color='k', linestyle='--', linewidth=1.)
dx.plot(t, scale_avg, 'k-', linewidth=1.5)
dx.set_title('d) {}--{} Anos (scale-averaged power)'.format(periodo_interesse[0], periodo_interesse[1]), fontsize=8)
dx.set_xlabel('Time (Year)')
dx.set_ylabel(r'Average variance [{}]'.format(units), fontsize=8)
dx.set_xlim([start_year, end_year]) # Define explicitamente os limites do eixo x

plt.savefig("Wavelets_NCEP.png", dpi=600)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
